# %% [markdown]
# https://www.perplexity.ai/search/b99dd1ac-2d40-4f7d-ba29-2972671abf18

# %%
import numpy as np

np.random.seed(22)
scores = np.random.randint(50, 101, size=(50,5))
scores

# %%
import pandas as pd

df = pd.DataFrame(scores,columns=["國文","英文","數學","生物","物理"],index=[f"學生{x}" for x in range(1,51)])
#設定表格每一欄、每一列的名稱
type(df) #df是DataFrame的實體
# Out:
# pandas.core.frame.DataFrame

# %%
[x**2 for x in range(10) if x< 4]
# Out:
# [0, 1, 4, 9]

# %%
df.columns.name = "科目" #設定欄資料名稱。DataFrame實體當中，有columns實體，columns實體屬性name。
df.index.name = "姓名" #設定列資料名稱
df
# Out:
# 科目    國文  英文   數學   生物  物理
# 姓名
# 學生1   54  94   50   86  88
# 學生2   93  70   58   81  86
# 學生3   79  68   64   95  74
# 學生4   79  89   84   91  58
# 學生5   90  55   97   77  70
# 學生6   84  79   68   67  88
# 學生7   69  69   52   77  57
# 學生8   77  89   73   96  92
# 學生9   73  91   61   80  63
# 學生10  61  89   97   99  51
# 學生11  97  73   69   98  79
# 學生12  79  51   79   71  94
# 學生13  59  70   67   53  86
# 學生14  61  79   82   68  93
# 學生15  53  56   65   78  82
# 學生16  89  75   66   71  74
# 學生17  64  67   58   74  69
# 學生18  92  92   83   55  56
# 學生19  95  55   56  100  55
# 學生20  72  50   87   99  67
# 學生21  68  75   91   82  71
# 學生22  57  72   83   62  90
# 學生23  70  65   71   71  55
# 學生24  54  54   69   50  58
# 學生25  92  66   83   71  56
# 學生26  84  88   87   88  92
# 學生27  56  76   62   86  79
# 學生28  70  61   90   83  84
# 學生29  64  85   88   50  69
# 學生30  59  53   97   56  72
# 學生31  78  90   89   51  69
# 學生32  77  89   67   99  52
# 學生33  94  74   78   60  60
# 學生34  50  58   51   77  88
# 學生35  93  75   50   85  94
# 學生36  92  66   81   89  52
# 學生37  60  56   75   72  63
# 學生38  74  88   77   87  69
# 學生39  85  68  100   92  73
# 學生40  91  66   88   58  88
# 學生41  90  65   72   62  78
# 學生42  81  93   56   87  71
# 學生43  79  63   94   84  73
# 學生44  92  89   97   79  61
# 學生45  53  84  100   95  68
# 學生46  59  90   98   60  95
# 學生47  97  71   58   89  73
# 學生48  89  68   67   77  72
# 學生49  80  59   98   59  50
# 學生50  66  70   52   87  70
